# %% [markdown]
# # Regresión lineal

# %% [markdown]
# Fabricando datos que muestren relación entre velocidad de página y cantidad comprada:

# %%
import numpy as np
from pylab import *

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, 0.1, 1000)) * 3

scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# Como solo tenemos 2 atributos, podemos simplemente usar scipy.state.linregress:

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)

# %% [markdown]
# Nuestro valor de R^2 muestra un resultado bueno (esperado):

# %%
r_value ** 2
# Out:
# 0.9901167998414562

# %% [markdown]
# Usamos la pendiente e intersección de nuestra regresión para graficar valores predichos vs. observados:

# %%
import matplotlib.pyplot as plt

def predict(x):
    return slope * x + intercept

fitLine = predict(pageSpeeds)

plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, fitLine, c='r')
plt.show()

# %% [markdown]
# ## Activity

# %% [markdown]
# Try increasing the random variation in the test data, and see what effect it has on the r-squared error value.
